# %%
#https://mykhel.com/football/la-liga-player-stats-l23/ 
# Importing modules I need in order to make graphs and stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sb
# Importing file from my desktop
df = pd.read_csv('Laliga.csv')
df.head()
# Out:
#             Player  Goals  Assists  Shots    MP
# 0    Karim Benzema     27       12     99  2596
# 1       Iago Aspas     18        6     65  3096
# 2  Vinicius Junior     17       10     62  2699
# 3    Raul De Tomas     17        3     86  2923
# 4           Juanmi     16        4     47  2145

# %%
# Getting variables
x = 'Goals'
y = 'Player'

# %%
# Making a bar graph with the variables
plt.bar(df[y], df[x], align='center', alpha=0.5)
plt.xlabel('Goals')
plt.title('Top 5 Laliga Players Goals During 21-22 Season')
# Out:
# Text(0.5, 1.0, 'Top 5 Laliga Players Goals During 21-22 Season')

# %%
# Getting variable and making a graph with it
s = 'Shots'

plt.barh(df[y], df[s], align='center', alpha=0.5)
plt.xlabel('Shots')
plt.title('Top 5 Laliga Players Shots During 21-22 Season')
# Out:
# Text(0.5, 1.0, 'Top 5 Laliga Players Shots During 21-22 Season')

# %%
# Getting variable and making a graph with it

m = 'MP'
plt.barh(df[y], df[m], align='center', alpha=0.5)
plt.xlabel('Minutes Played')
plt.title('Top 5 Laliga Players Minutes Played During 21-22 Season')
# Out:
# Text(0.5, 1.0, 'Top 5 Laliga Players Minutes Played During 21-22 Season')

# %%
# Importing modules for making a bar graph 
import numpy as np 
import matplotlib.pyplot as plt 
  # List of variables I need from df
X = list(df[y])
goals = df[x]
assists = df[a]
shots = df[s]
minutes = df[m]

X_axis = np.arange(len(X))
# Plotting it 
plt.figure(figsize = (10,10))
plt.bar(X_axis - 0.2, goals, 0.2, label = 'Goals')
plt.bar(X_axis + 0.2, assists, 0.2, label = 'Assists')
plt.bar(X_axis, shots, 0.2, label = 'shots')
# Labels for graph
plt.xticks(X_axis, X)
plt.xlabel("Players")
plt.ylabel("Amount")
plt.title("Top 5 Laliga Players Goals, Assists, and Shots During 21-22 Season")
plt.legend()
plt.show()
